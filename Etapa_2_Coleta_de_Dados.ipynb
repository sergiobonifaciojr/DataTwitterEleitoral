# %% [markdown]
# <a href="https://colab.research.google.com/github/sergiobonifaciojr/DataTwitterEleitoral/blob/main/Etapa_2_Coleta_de_Dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Coleta de Dados**

# %% [markdown]
# Proposta para construção de uma aplicação que realiza análise de sentimento dos candidatos a Presidência.

# %% [markdown]
# ***Instalação das Bibliotecas***

# %%
pip install snscrape

# %% [markdown]
# Importando as Bibliotecas

# %%
import snscrape.modules.twitter as sntwitter

# Manipulação de Dados
import pandas as pd

# %%
maximo_de_tweets = 50

# %% [markdown]
# ### Lula

# %%
lista_tweets_lula = []

# %%
for i, tweet in enumerate(sntwitter.TwitterSearchScraper(['lula']).get_items()):
  if i > maximo_de_tweets:
    break
  lista_tweets_lula.append([tweet.date, tweet.id, tweet.content])

# %%
lista_tweets_lula

# %%
dataframe_tweets_lula = pd.DataFrame(lista_tweets_lula, columns=['Data_Hora', 'IdTweet', 'Tweet'])

# %%
dataframe_tweets_lula.head()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-07-30 21:56:23+00:00  1553499774732599312
# 1 2022-07-30 21:56:23+00:00  1553499773126180865
# 2 2022-07-30 21:56:22+00:00  1553499770773245952
# 3 2022-07-30 21:56:22+00:00  1553499770378928134
# 4 2022-07-30 21:56:21+00:00  1553499766763536384
#
#                                                Tweet
# 0  @LulaOficial Sabemos o que fez no verão passad...
# 1  @LuisDerieul Mentiroso. Lula tá aqui no Ceará ...
# 2  @senadorhumberto @LulaOficial Só se vê grama.....
# 3   @SF_Moro Tu tá com o Lula Marreco, para de show!
# 4  @LulaOficial @ricardostuckert Duvido que tenha...

# %%
dataframe_tweets_lula['Candidato'] = 'Lula'

# %%
dataframe_tweets_lula.head()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-07-30 21:56:23+00:00  1553499774732599312
# 1 2022-07-30 21:56:23+00:00  1553499773126180865
# 2 2022-07-30 21:56:22+00:00  1553499770773245952
# 3 2022-07-30 21:56:22+00:00  1553499770378928134
# 4 2022-07-30 21:56:21+00:00  1553499766763536384
#
#                                                Tweet Candidato
# 0  @LulaOficial Sabemos o que fez no verão passad...      Lula
# 1  @LuisDerieul Mentiroso. Lula tá aqui no Ceará ...      Lula
# 2  @senadorhumberto @LulaOficial Só se vê grama.....      Lula
# 3   @SF_Moro Tu tá com o Lula Marreco, para de show!      Lula
# 4  @LulaOficial @ricardostuckert Duvido que tenha...      Lula

# %% [markdown]
# # **Bolsonaro**

# %%
lista_tweets_bolsonaro = []

# %%
for i, tweet in enumerate(sntwitter.TwitterSearchScraper(['bolsonaro']).get_items()):
  if i > maximo_de_tweets:
    break
  lista_tweets_bolsonaro.append([tweet.date, tweet.id, tweet.content])

# %%
dataframe_tweets_bolsonaro = pd.DataFrame(lista_tweets_bolsonaro, columns=['Data_Hora', 'IdTweet', 'Tweet'])

# %%
dataframe_tweets_bolsonaro.head()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-07-30 22:06:22+00:00  1553502287355584524
# 1 2022-07-30 22:06:22+00:00  1553502285984141313
# 2 2022-07-30 22:06:21+00:00  1553502283610165254
# 3 2022-07-30 22:06:20+00:00  1553502278551830528
# 4 2022-07-30 22:06:19+00:00  1553502273677959169
#
#                                                Tweet
# 0  Não entendo essa gente que coloca fora Bolsona...
# 1  @arivsilva1 @FatimaF46328259 @Delinho17333581 ...
# 2  @brunnoalves @AnnaCroft19 @lia_liaa22 @jairbol...
# 3  "É Bolsonaro" #CapitaoNoPrimeiroTurno https://...
# 4  Alguém pode informar para Miriam Leitoa da Red...

# %%
dataframe_tweets_bolsonaro['Candidato'] = 'Bolsonaro'

# %%
dataframe_tweets_bolsonaro.head()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-07-30 22:06:22+00:00  1553502287355584524
# 1 2022-07-30 22:06:22+00:00  1553502285984141313
# 2 2022-07-30 22:06:21+00:00  1553502283610165254
# 3 2022-07-30 22:06:20+00:00  1553502278551830528
# 4 2022-07-30 22:06:19+00:00  1553502273677959169
#
#                                                Tweet  Candidato
# 0  Não entendo essa gente que coloca fora Bolsona...  Bolsonaro
# 1  @arivsilva1 @FatimaF46328259 @Delinho17333581 ...  Bolsonaro
# 2  @brunnoalves @AnnaCroft19 @lia_liaa22 @jairbol...  Bolsonaro
# 3  "É Bolsonaro" #CapitaoNoPrimeiroTurno https://...  Bolsonaro
# 4  Alguém pode informar para Miriam Leitoa da Red...  Bolsonaro

# %% [markdown]
# ### Ciro Gomes

# %%
lista_tweets_ciro = []

# %%
for i, tweet in enumerate(sntwitter.TwitterSearchScraper(['ciro gomes']).get_items()):
  if i > maximo_de_tweets:
    break
  lista_tweets_ciro.append([tweet.date, tweet.id, tweet.content])

# %%
dataframe_tweets_ciro = pd.DataFrame(lista_tweets_ciro, columns=['Data_Hora', 'IdTweet', 'Tweet'])

# %%
dataframe_tweets_ciro.head()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-07-30 22:11:20+00:00  1553503535689568259
# 1 2022-07-30 22:11:09+00:00  1553503492010086404
# 2 2022-07-30 22:10:48+00:00  1553503401757081602
# 3 2022-07-30 22:10:40+00:00  1553503370853376001
# 4 2022-07-30 22:10:39+00:00  1553503363844771841
#
#                                                Tweet
# 0  Não deveria..Ciro Gomes funciona como linha Au...
# 1  Resolve tanto que elegeu Bolsonaro, enquanto T...
# 2  @parox40 @cirogomes Foi nesse dia aqui https:/...
# 3  @ANTONIO72762204 @cirogomes Nem no Ceará o cor...
# 4                    @Cristia00945910 @cirogomes 👊✌️

# %%
dataframe_tweets_ciro['Candidato'] = 'Ciro Gomes'

# %%
dataframe_tweets_ciro.head()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-07-30 22:11:20+00:00  1553503535689568259
# 1 2022-07-30 22:11:09+00:00  1553503492010086404
# 2 2022-07-30 22:10:48+00:00  1553503401757081602
# 3 2022-07-30 22:10:40+00:00  1553503370853376001
# 4 2022-07-30 22:10:39+00:00  1553503363844771841
#
#                                                Tweet   Candidato
# 0  Não deveria..Ciro Gomes funciona como linha Au...  Ciro Gomes
# 1  Resolve tanto que elegeu Bolsonaro, enquanto T...  Ciro Gomes
# 2  @parox40 @cirogomes Foi nesse dia aqui https:/...  Ciro Gomes
# 3  @ANTONIO72762204 @cirogomes Nem no Ceará o cor...  Ciro Gomes
# 4                    @Cristia00945910 @cirogomes 👊✌️  Ciro Gomes

# %%
dataframe_final = pd.concat([dataframe_tweets_lula, dataframe_tweets_bolsonaro, dataframe_tweets_ciro], axis=0)

# %%
dataframe_final.head()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-07-30 21:56:23+00:00  1553499774732599312
# 1 2022-07-30 21:56:23+00:00  1553499773126180865
# 2 2022-07-30 21:56:22+00:00  1553499770773245952
# 3 2022-07-30 21:56:22+00:00  1553499770378928134
# 4 2022-07-30 21:56:21+00:00  1553499766763536384
#
#                                                Tweet Candidato
# 0  @LulaOficial Sabemos o que fez no verão passad...      Lula
# 1  @LuisDerieul Mentiroso. Lula tá aqui no Ceará ...      Lula
# 2  @senadorhumberto @LulaOficial Só se vê grama.....      Lula
# 3   @SF_Moro Tu tá com o Lula Marreco, para de show!      Lula
# 4  @LulaOficial @ricardostuckert Duvido que tenha...      Lula

# %%
dataframe_final['Candidato'].unique()
# Out:
# array(['Lula', 'Bolsonaro', 'Ciro Gomes'], dtype=object)

# %%
dataframe_final.to_csv('dataframe_final_candidatos.csv', sep=',', index=False)

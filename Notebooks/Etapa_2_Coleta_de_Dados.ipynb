# %% [markdown]
# # **Coleta de Dados**

# %% [markdown]
# Proposta para construção de uma aplicação que realiza análise de sentimento dos candidatos a Presidência.

# %% [markdown]
# ***Instalação das Bibliotecas***

# %%
pip install snscrape
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: snscrape in /usr/local/lib/python3.7/dist-packages (0.3.4)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.7/dist-packages (from snscrape) (2.23.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from snscrape) (4.2.6)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from snscrape) (4.6.3)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->snscrape) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->snscrape) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->snscrape) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->snscrape) (3.0.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->snscrape) (1.7.1)

# %% [markdown]
# Importando as Bibliotecas

# %%
import snscrape.modules.twitter as sntwitter

# Manipulação de Dados
import pandas as pd

# %%
maximo_de_tweets = 50

# %% [markdown]
# ### Lula

# %%
lista_tweets_lula = []

# %%
for i, tweet in enumerate(sntwitter.TwitterSearchScraper(['lula']).get_items()):
  if i > maximo_de_tweets:
    break
  lista_tweets_lula.append([tweet.date, tweet.id, tweet.content])

# %%
lista_tweets_lula
# Out:
# [[datetime.datetime(2022, 7, 30, 23, 19, 38, tzinfo=datetime.timezone.utc),
#   1553520723708334081,
#   '@gleisi @LulaOficial @CamiloSantanaCE @elmanofreitaspt Muito mas muito mal editada até  uma criança  consegue ver...vocês  não  engansm mais ninguémmmmmmmmmmm'],
#  [datetime.datetime(2022, 7, 30, 23, 19, 37, tzinfo=datetime.timezone.utc),
#   1553520720952582151,
#   '@sbasilio28 @guispfreitas @jfernandaBrasil @LeoHidSouza @AndreJanonesAdv @LulaOficial @CaboDaciolo @davidmirandario @gisellebezerra ✨ não tem que ter segundo turno ✨\nNão é sobre ganhar ou perder no segundo turno, é sobre GOLPE'],
#  [datetime.datetime(2022, 7, 30, 23, 19, 37, tzinfo=datetime.timezone.utc),
#   1553520720939974656,
#   '🗣🎤🎼🎵🥁Lula ladrão seu lugar é na prisão🎶🎵\U0001fa95🎶🎸\n#capitaodopovo \n#CapitaoDoPovoQueVaiVencerDenovo https://t.co/EU1gk09cSn'],
#  [datetime.datetime(2022, 7, 30, 23, 19, 37, tzinfo=datetime.timezone.utc),
#   1553520718675050497,
#   '@LulaOficial https://t.co/baFbe7aolm'],
#  [datetime.datetime(2022, 7, 30, 23, 19, 36, tzinfo=datetime.timezone.utc),
#   1553520718431895553,
#   '@geraldoalckmin @LulaOficial @PSBNacional40 @ptbrasil @csiqueirapsb Querem voltar os dois para a cena do crime 🤦🏻\u200d♂️ https://t.co/iIAdqSPFiX'],
#  [datetime.datetime(2022, 7, 30, 23, 19, 36, tzinfo=datetime.timezone.utc),
#   1553520718113128448,
#   '@LulaOficial @ricardostuckert https://t.co/6VkNQ20wfN'],
#  [datetime.datetime(2022, 7, 30, 23, 19, 36, tzinfo=datetime.timezone.utc),
#   1553520717785866241,
#   '@LulaOficial @dilmabr https://t.co/SwdEiZjbpN'],
#  [datetime.datetime(2022, 7, 30, 23, 19, 36, tzinfo=datetime.timezone.utc),
#   1553520717735550977,
#   '@LulaOficial O #capitaodopovo https://t.co/vYUoq3jg9u'],
#  [datetime.datetime(2022, 7, 30, 23, 19, 36, tzinfo=datetime.timezone.utc),
#   1553520717077139458,
#   '@LulaOficial Lula ladrao voto pra você nunca mais o Brasil e bolsonaro'],
#  [datetime.datetime(2022, 7, 30, 23, 19, 34, tzinfo=datetime.timezone.utc),
#   1553520709812584449,
#   '@LulaOficial Devia estar sofrendo na cadeia'],
#  [datetime.datetime(2022, 7, 30, 23, 19, 34, tzinfo=datetime.timezone.utc),
#   1553520707828686849,
#   'cara sinceramente lula não devia ser candidato\nnão porque ele é corrupto mas sim porque o cara é candidato a presidente do país desde 1989 \n33 ANOS porra já chega'],
#  [datetime.datetime(2022, 7, 30, 23, 19, 34, tzinfo=datetime.timezone.utc),
#   1553520706800984064,
#   '@renancalheiros @LulaOficial Kkkkkk picareta mor, golpista, jogou o Brasil na crise... agora fica aí pagando de democrata progressista... pqp viu'],
#  [datetime.datetime(2022, 7, 30, 23, 19, 33, tzinfo=datetime.timezone.utc),
#   1553520704670367745,
#   '@senadorhumberto O choro é livre!!! E @LulaOficial irá ao encontro do eleitor quando? 😂😂🎪🎪🎪'],
#  [datetime.datetime(2022, 7, 30, 23, 19, 33, tzinfo=datetime.timezone.utc),
#   1553520702275321861,
#   '@LulaOficial Iniciou bem e terminou mal. Bolsonaro= a democracia e Lula=a corrupção e autoritarismo'],
#  [datetime.datetime(2022, 7, 30, 23, 19, 32, tzinfo=datetime.timezone.utc),
#   1553520697951096833,
#   '@CNNBrasil Cnn transmite dake news pró Lula'],
#  [datetime.datetime(2022, 7, 30, 23, 19, 31, tzinfo=datetime.timezone.utc),
#   1553520696617320453,
#   '@LulaOficial @ricardostuckert Venezuela?🤔'],
#  [datetime.datetime(2022, 7, 30, 23, 19, 31, tzinfo=datetime.timezone.utc),
#   1553520696428478465,
#   '@LulaOficial @elmanofreitaspt @CamiloSantanaCE @ricardostuckert E o Pré-candidato @LulaOficial vai RECONSTRUIR tudo que destruíram. \n#LulaEoPTReconstruirOBrasil \n#SouLula https://t.co/X6WnKiZKN7'],
#  [datetime.datetime(2022, 7, 30, 23, 19, 31, tzinfo=datetime.timezone.utc),
#   1553520696428470272,
#   '@ThiagoResiste @LulaOficial @ricardostuckert https://t.co/bfRwc1VAHA'],
#  [datetime.datetime(2022, 7, 30, 23, 19, 31, tzinfo=datetime.timezone.utc),
#   1553520696420188163,
#   '@LulaOficial @ItaloArruda'],
#  [datetime.datetime(2022, 7, 30, 23, 19, 31, tzinfo=datetime.timezone.utc),
#   1553520695484846082,
#   '@jairmearrependi @LulaOficial ⭐️'],
#  [datetime.datetime(2022, 7, 30, 23, 19, 31, tzinfo=datetime.timezone.utc),
#   1553520694708822026,
#   '@ThiagoResiste @LulaOficial @ricardostuckert Os vagabundos,ladrões e marginais, esses estão com vcs. 3 podem ficar com eles.'],
#  [datetime.datetime(2022, 7, 30, 23, 19, 30, tzinfo=datetime.timezone.utc),
#   1553520692401946626,
#   '@augustodeAB Ele Ajudou lula né? Deve tá queimando.'],
#  [datetime.datetime(2022, 7, 30, 23, 19, 30, tzinfo=datetime.timezone.utc),
#   1553520692070678529,
#   '@LulaOficial NAO conte comigo, Não sei nem quem é você na fila do pão.ok?'],
#  [datetime.datetime(2022, 7, 30, 23, 19, 30, tzinfo=datetime.timezone.utc),
#   1553520691131072512,
#   '@LulaOficial @LulaOficial Parque do Povo'],
#  [datetime.datetime(2022, 7, 30, 23, 19, 30, tzinfo=datetime.timezone.utc),
#   1553520690095132672,
#   '@moura_101 @moura_101  e o Moro que sairá no mesmo Santinho do Lula ?'],
#  [datetime.datetime(2022, 7, 30, 23, 19, 29, tzinfo=datetime.timezone.utc),
#   1553520686513197057,
#   '@ptbrasil @LulaOficial Deus nos livre ....se ele pretende fazer 40 em 4 não vai sobra nada nesse país pra ser roubado.....kkkkkkkkkk'],
#  [datetime.datetime(2022, 7, 30, 23, 19, 28, tzinfo=datetime.timezone.utc),
#   1553520682499293184,
#   '@LulaOficial Uma vergonha de presidente esse pária mundial, JAIL BOLSORATO'],
#  [datetime.datetime(2022, 7, 30, 23, 19, 27, tzinfo=datetime.timezone.utc),
#   1553520679512932360,
#   '@renancalheiros @LulaOficial Vagabundos'],
#  [datetime.datetime(2022, 7, 30, 23, 19, 27, tzinfo=datetime.timezone.utc),
#   1553520677558304770,
#   '@RomersonCruz @amandacostapi O Lula terá o apoio dele!'],
#  [datetime.datetime(2022, 7, 30, 23, 19, 26, tzinfo=datetime.timezone.utc),
#   1553520675968745474,
#   '@Rosamoura05Rosa @LulaOficial Tinha que ter lei para colocar apoiadores de ladrao na cadeiaaaaaaaa'],
#  [datetime.datetime(2022, 7, 30, 23, 19, 26, tzinfo=datetime.timezone.utc),
#   1553520674693595141,
#   '@LulaOficial Quando vem a São Luís ?!'],
#  [datetime.datetime(2022, 7, 30, 23, 19, 26, tzinfo=datetime.timezone.utc),
#   1553520673770938368,
#   '@LulaOficial @elmanofreitaspt @CamiloSantanaCE @ricardostuckert https://t.co/xPAiWZ2XEW'],
#  [datetime.datetime(2022, 7, 30, 23, 19, 26, tzinfo=datetime.timezone.utc),
#   1553520673548550145,
#   '@GilvaniaTavar10 @gleisi @LulaOficial @CamiloSantanaCE @elmanofreitaspt O evento foi no centro de eventos de Fortaleza, que é fechado, sua jumenta...'],
#  [datetime.datetime(2022, 7, 30, 23, 19, 26, tzinfo=datetime.timezone.utc),
#   1553520673473052672,
#   '@marcofeliciano Agora eu voto no Lula com força 📢'],
#  [datetime.datetime(2022, 7, 30, 23, 19, 26, tzinfo=datetime.timezone.utc),
#   1553520673133395969,
#   '@LulaOficial https://t.co/aYexKOQK8B'],
#  [datetime.datetime(2022, 7, 30, 23, 19, 25, tzinfo=datetime.timezone.utc),
#   1553520668980944897,
#   'Tremendo comicio em Fortaleza. Uma multidão por Lula, @LulaOficial, e Elmano Freitas, @elmanofreitaspt. No estado de Ciro Gomes, uma resposta à altura de suas diatribes contra o PT e mais um tranco em Jair Bolsonaro. Outro passo adiante na caminhada da vitória. https://t.co/7w2UNMDSCl'],
#  [datetime.datetime(2022, 7, 30, 23, 19, 25, tzinfo=datetime.timezone.utc),
#   1553520668528066561,
#   '@ThiagoResiste É Lula Presidente'],
#  [datetime.datetime(2022, 7, 30, 23, 19, 24, tzinfo=datetime.timezone.utc),
#   1553520666976165888,
#   '@folkalwyn13 @LulaOficial @CamiloSantanaCE @elmanofreitaspt @ricardostuckert Ele foi juldado e preso Jumento?'],
#  [datetime.datetime(2022, 7, 30, 23, 19, 23, tzinfo=datetime.timezone.utc),
#   1553520662022684672,
#   'Pegue o Auxílio Brasil do Bolsonaro, feito apenas na reta final do seu mandato, mas em 2 de outubro vote em Lula para ter de volta o Bolsa Família e outros programas reais de distribuição de renda, geração de empregos e redução das desigualdades.\n#LulaEoPTReconstruirOBrasil https://t.co/iLdlimrymR'],
#  [datetime.datetime(2022, 7, 30, 23, 19, 23, tzinfo=datetime.timezone.utc),
#   1553520661460668417,
#   '@tabataamaralsp Tabaca tem que apoiar Lula'],
#  [datetime.datetime(2022, 7, 30, 23, 19, 22, tzinfo=datetime.timezone.utc),
#   1553520658524545026,
#   '@ThiagoResiste @LulaOficial @ricardostuckert https://t.co/aKd6NWYbYT'],
#  [datetime.datetime(2022, 7, 30, 23, 19, 21, tzinfo=datetime.timezone.utc),
#   1553520653017440257,
#   '@LulaOficial @elmanofreitaspt @CamiloSantanaCE @ricardostuckert Mostra vídeo luladrão. Não tem apoio nenhum né ? Tem qyebudar foto fake'],
#  [datetime.datetime(2022, 7, 30, 23, 19, 21, tzinfo=datetime.timezone.utc),
#   1553520652107350016,
#   'Data folha divulga nova pesquisa de intenção de votos.\n57% Lula 🐙\n42% Bolsonaro 🇧🇷\n11% Ciro Gomes 🐟\n8% Simone Tebet 🤮\n6% Marina Silva 🦖\n14% Brancos / nulos ⚪️\n12% Indecisos ❓️❗️\n\nA pesquisa entrevistou 1313 pessoas entre os dias 30 de fev. e 01 de abr.'],
#  [datetime.datetime(2022, 7, 30, 23, 19, 20, tzinfo=datetime.timezone.utc),
#   1553520651356471299,
#   '@DeputadoFederal @LulaOficial Vdd'],
#  [datetime.datetime(2022, 7, 30, 23, 19, 20, tzinfo=datetime.timezone.utc),
#   1553520649565573121,
#   'Chocada na feira Benedito Calixto (São Paulo) hj, onde vai povo descolado. \nO tio da 1a. barraca ficou brabo que eu panfletava pra Lula-Boulos. Subiu o tom, ficou roxo e berrou "COMUNISTA!"\n(Meu deleite 🙂) \nSó deixando alerta aqui pra quem não compra de bolsonarista 🙋🏻\u200d♀️\n#SouLula'],
#  [datetime.datetime(2022, 7, 30, 23, 19, 20, tzinfo=datetime.timezone.utc),
#   1553520648810528768,
#   '@LulaOficial Medo do povo. Disse td 👏🏻👏🏻👏🏻👏🏻👏🏻'],
#  [datetime.datetime(2022, 7, 30, 23, 19, 20, tzinfo=datetime.timezone.utc),
#   1553520648475086852,
#   '@ptbrasil @LulaOficial https://t.co/jaknFC3m5s'],
#  [datetime.datetime(2022, 7, 30, 23, 19, 19, tzinfo=datetime.timezone.utc),
#   1553520646595952644,
#   '@CamiloSantanaCE @ricardostuckert @LulaOficial @elmanofreitaspt #luladraoteulugarnaprisao'],
#  [datetime.datetime(2022, 7, 30, 23, 19, 18, tzinfo=datetime.timezone.utc),
#   1553520642678525958,
#   '@LulaOficial @elmanofreitaspt @CamiloSantanaCE @ricardostuckert Luladrão'],
#  [datetime.datetime(2022, 7, 30, 23, 19, 18, tzinfo=datetime.timezone.utc),
#   1553520639520264192,
#   '@LulaOficial @dilmabr Além de mentiroso é ladrão!'],
#  [datetime.datetime(2022, 7, 30, 23, 19, 16, tzinfo=datetime.timezone.utc),
#   1553520634390630400,
#   '@ThiagoResiste @LulaOficial @ricardostuckert https://t.co/BOi1rguctq']]

# %%
dataframe_tweets_lula = pd.DataFrame(lista_tweets_lula, columns=['Data_Hora', 'IdTweet', 'Tweet'])

# %%
dataframe_tweets_lula.head()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-07-30 23:19:38+00:00  1553520723708334081
# 1 2022-07-30 23:19:37+00:00  1553520720952582151
# 2 2022-07-30 23:19:37+00:00  1553520720939974656
# 3 2022-07-30 23:19:37+00:00  1553520718675050497
# 4 2022-07-30 23:19:36+00:00  1553520718431895553
#
#                                                Tweet
# 0  @gleisi @LulaOficial @CamiloSantanaCE @elmanof...
# 1  @sbasilio28 @guispfreitas @jfernandaBrasil @Le...
# 2  🗣🎤🎼🎵🥁Lula ladrão seu lugar é na prisão🎶🎵🪕🎶🎸\n#...
# 3               @LulaOficial https://t.co/baFbe7aolm
# 4  @geraldoalckmin @LulaOficial @PSBNacional40 @p...

# %%
dataframe_tweets_lula['Candidato'] = 'Lula'

# %%
dataframe_tweets_lula.head()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-07-30 23:19:38+00:00  1553520723708334081
# 1 2022-07-30 23:19:37+00:00  1553520720952582151
# 2 2022-07-30 23:19:37+00:00  1553520720939974656
# 3 2022-07-30 23:19:37+00:00  1553520718675050497
# 4 2022-07-30 23:19:36+00:00  1553520718431895553
#
#                                                Tweet Candidato
# 0  @gleisi @LulaOficial @CamiloSantanaCE @elmanof...      Lula
# 1  @sbasilio28 @guispfreitas @jfernandaBrasil @Le...      Lula
# 2  🗣🎤🎼🎵🥁Lula ladrão seu lugar é na prisão🎶🎵🪕🎶🎸\n#...      Lula
# 3               @LulaOficial https://t.co/baFbe7aolm      Lula
# 4  @geraldoalckmin @LulaOficial @PSBNacional40 @p...      Lula

# %% [markdown]
# # **Bolsonaro**

# %%
lista_tweets_bolsonaro = []

# %%
for i, tweet in enumerate(sntwitter.TwitterSearchScraper(['bolsonaro']).get_items()):
  if i > maximo_de_tweets:
    break
  lista_tweets_bolsonaro.append([tweet.date, tweet.id, tweet.content])

# %%
dataframe_tweets_bolsonaro = pd.DataFrame(lista_tweets_bolsonaro, columns=['Data_Hora', 'IdTweet', 'Tweet'])

# %%
dataframe_tweets_bolsonaro.head()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-07-30 23:19:39+00:00  1553520730356187136
# 1 2022-07-30 23:19:39+00:00  1553520727608918016
# 2 2022-07-30 23:19:37+00:00  1553520720751333377
# 3 2022-07-30 23:19:36+00:00  1553520717077139458
# 4 2022-07-30 23:19:35+00:00  1553520713247723521
#
#                                                Tweet
# 0  @PauloMartins10 @jairbolsonaro @ratinho_jr Ess...
# 1  @ZilaHelena @MarcioM61326104 @adinaelsilva @Al...
# 2  “Meu amigo tem pau grande. E o sabor é excelen...
# 3  @LulaOficial Lula ladrao voto pra você nunca m...
# 4  @VEJA TRAGÉDIA É NESTE MOMENTO AINDA TER ESTE ...

# %%
dataframe_tweets_bolsonaro['Candidato'] = 'Bolsonaro'

# %%
dataframe_tweets_bolsonaro.head()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-07-30 23:19:39+00:00  1553520730356187136
# 1 2022-07-30 23:19:39+00:00  1553520727608918016
# 2 2022-07-30 23:19:37+00:00  1553520720751333377
# 3 2022-07-30 23:19:36+00:00  1553520717077139458
# 4 2022-07-30 23:19:35+00:00  1553520713247723521
#
#                                                Tweet  Candidato
# 0  @PauloMartins10 @jairbolsonaro @ratinho_jr Ess...  Bolsonaro
# 1  @ZilaHelena @MarcioM61326104 @adinaelsilva @Al...  Bolsonaro
# 2  “Meu amigo tem pau grande. E o sabor é excelen...  Bolsonaro
# 3  @LulaOficial Lula ladrao voto pra você nunca m...  Bolsonaro
# 4  @VEJA TRAGÉDIA É NESTE MOMENTO AINDA TER ESTE ...  Bolsonaro

# %% [markdown]
# ### Ciro Gomes

# %%
lista_tweets_ciro = []

# %%
for i, tweet in enumerate(sntwitter.TwitterSearchScraper(['ciro gomes']).get_items()):
  if i > maximo_de_tweets:
    break
  lista_tweets_ciro.append([tweet.date, tweet.id, tweet.content])

# %%
dataframe_tweets_ciro = pd.DataFrame(lista_tweets_ciro, columns=['Data_Hora', 'IdTweet', 'Tweet'])

# %%
dataframe_tweets_ciro.head()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-07-30 23:19:25+00:00  1553520668980944897
# 1 2022-07-30 23:19:21+00:00  1553520652107350016
# 2 2022-07-30 23:19:18+00:00  1553520641202069504
# 3 2022-07-30 23:19:04+00:00  1553520583421427712
# 4 2022-07-30 23:18:36+00:00  1553520464311492610
#
#                                                Tweet
# 0  Tremendo comicio em Fortaleza. Uma multidão po...
# 1  Data folha divulga nova pesquisa de intenção d...
# 2  @dadosantana77 @cirogomes Mais do que na hora ...
# 3  Depois da bandeirinha do PT, vi pela primeira ...
# 4                 @BlogdoNoblat @cirogomes arregou ?

# %%
dataframe_tweets_ciro['Candidato'] = 'Ciro Gomes'

# %%
dataframe_tweets_ciro.head()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-07-30 23:19:25+00:00  1553520668980944897
# 1 2022-07-30 23:19:21+00:00  1553520652107350016
# 2 2022-07-30 23:19:18+00:00  1553520641202069504
# 3 2022-07-30 23:19:04+00:00  1553520583421427712
# 4 2022-07-30 23:18:36+00:00  1553520464311492610
#
#                                                Tweet   Candidato
# 0  Tremendo comicio em Fortaleza. Uma multidão po...  Ciro Gomes
# 1  Data folha divulga nova pesquisa de intenção d...  Ciro Gomes
# 2  @dadosantana77 @cirogomes Mais do que na hora ...  Ciro Gomes
# 3  Depois da bandeirinha do PT, vi pela primeira ...  Ciro Gomes
# 4                 @BlogdoNoblat @cirogomes arregou ?  Ciro Gomes

# %%
dataframe_final = pd.concat([dataframe_tweets_lula, dataframe_tweets_bolsonaro, dataframe_tweets_ciro], axis=0)

# %%
dataframe_final.head()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-07-30 23:19:38+00:00  1553520723708334081
# 1 2022-07-30 23:19:37+00:00  1553520720952582151
# 2 2022-07-30 23:19:37+00:00  1553520720939974656
# 3 2022-07-30 23:19:37+00:00  1553520718675050497
# 4 2022-07-30 23:19:36+00:00  1553520718431895553
#
#                                                Tweet Candidato
# 0  @gleisi @LulaOficial @CamiloSantanaCE @elmanof...      Lula
# 1  @sbasilio28 @guispfreitas @jfernandaBrasil @Le...      Lula
# 2  🗣🎤🎼🎵🥁Lula ladrão seu lugar é na prisão🎶🎵🪕🎶🎸\n#...      Lula
# 3               @LulaOficial https://t.co/baFbe7aolm      Lula
# 4  @geraldoalckmin @LulaOficial @PSBNacional40 @p...      Lula

# %%
dataframe_final['Candidato'].unique()
# Out:
# array(['Lula', 'Bolsonaro', 'Ciro Gomes'], dtype=object)

# %%
dataframe_final.to_csv('dataframe_final_candidatos.csv', sep=',', index=False)
